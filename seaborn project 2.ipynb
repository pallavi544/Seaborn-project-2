# %%
import pandas as pd

# %%
df=pd.read_csv("Obesity Classification.csv")
df
# Out:
#       ID  Age  Gender  Height  Weight   BMI          Label
# 0      1   25    Male     175      80  25.3  Normal Weight
# 1      2   30  Female     160      60  22.5  Normal Weight
# 2      3   35    Male     180      90  27.3     Overweight
# 3      4   40  Female     150      50  20.0    Underweight
# 4      5   45    Male     190     100  31.2          Obese
# ..   ...  ...     ...     ...     ...   ...            ...
# 103  106   11    Male     175      10   3.9    Underweight
# 104  107   16  Female     160      10   3.9    Underweight
# 105  108   21    Male     180      15   5.6    Underweight
# 106  109   26  Female     150      15   5.6    Underweight
# 107  110   31    Male     190      20   8.3    Underweight
#
# [108 rows x 7 columns]

# %% [markdown]
# ### Isna,Dtypes,Describe,column

# %%
df.isna().sum()
# Out:
# ID        0
# Age       0
# Gender    0
# Height    0
# Weight    0
# BMI       0
# Label     0
# dtype: int64

# %%
df.dtypes
# Out:
# ID          int64
# Age         int64
# Gender     object
# Height      int64
# Weight      int64
# BMI       float64
# Label      object
# dtype: object

# %%
df.describe()
# Out:
#                ID         Age      Height      Weight         BMI
# count  108.000000  108.000000  108.000000  108.000000  108.000000
# mean    56.046296   46.555556  166.574074   59.490741   20.549074
# std     31.917939   24.720620   27.873615   28.856233    7.583818
# min      1.000000   11.000000  120.000000   10.000000    3.900000
# 25%     28.750000   27.000000  140.000000   35.000000   16.700000
# 50%     56.500000   42.500000  175.000000   55.000000   21.200000
# 75%     83.250000   59.250000  190.000000   85.000000   26.100000
# max    110.000000  112.000000  210.000000  120.000000   37.200000

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Height', 'Weight', 'BMI', 'Label'], dtype='object')

# %% [markdown]
# ## Seaborn Graphs

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data=df,x="BMI",kde=True,stat='frequency')
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(data=df,x='Age',y='BMI',hue='Gender')
plt.xlabel("Age")

plt.ylabel("BMI")

plt.title("Relationship between Age and BMI")
plt.show()

# %%
sns.scatterplot(data=df,x='Age',y='Weight',hue='Gender',size='BMI',sizes=(50,100))
plt.xlabel("Age")

plt.ylabel("Weight")

plt.title("Relationship between Age and Weight")
plt.show()

# %% [markdown]
# ### Barplot

# %%
sns.barplot(y='Age',x='Label',data=df,hue='Gender')
plt.xlabel("label")
plt.ylabel("Age")
plt.title("Relationship between Age and Label")
plt.show()

# %%
sns.barplot(y='BMI',x='Gender',data=df,color='pink')
plt.xlabel("Gender")
plt.ylabel("BMI")
plt.title("Relationship between Gender and BMI")
plt.show()

# %%
sns.barplot(y='Weight',x='Gender',data=df,color='skyblue')
plt.xlabel("Gender")
plt.ylabel("Weight")
plt.title("Relationship between Gender and weight")
plt.show()

# %%
sns.barplot(y='Height',x='Gender',data=df,color='magenta')
plt.xlabel("Gender")
plt.ylabel("Height")
plt.title("Relationship between Gender and Height")
plt.show()

# %% [markdown]
# ### stirplot and Swarmplot

# %%
sns.stripplot(y='Age',x='Label',data=df,hue='Gender')
plt.show()

# %%
sns.swarmplot(y='BMI',x='Gender',data=df,color='pink')
plt.show()

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x='Gender',data=df)
plt.show()

# %%
sns.countplot(x='Label',data=df,color="green")
plt.show()

# %% [markdown]
# ### Boxplot and Violinplot

# %%
sns.boxplot(x='Label',y='Age',hue='Gender',data=df)
plt.show()

# %%
sns.boxplot(y='BMI',x='Gender',data=df)
plt.show()

# %%
sns.violinplot(x='Label',y='Age',data=df)
plt.show()

# %% [markdown]
# ### KDEplot and Regression plot

# %%
sns.kdeplot(data=df,x='Age',y='BMI',shade=True,color='red')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9520\683715144.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df,x='Age',y='BMI',shade=True,color='red')
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
sns.regplot(data=df,x='Age',y='BMI')
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %% [markdown]
# ### Pairplot and Jointplot

# %%
sns.pairplot(df)

# %%
sns.jointplot(data=df,x='Age',y='BMI',kind='scatter')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in ['Gender','Label']:
    df[column]=le.fit_transform(df[column])

# %%
df
# Out:
#       ID  Age  Gender  Height  Weight   BMI  Label
# 0      1   25       1     175      80  25.3      0
# 1      2   30       0     160      60  22.5      0
# 2      3   35       1     180      90  27.3      2
# 3      4   40       0     150      50  20.0      3
# 4      5   45       1     190     100  31.2      1
# ..   ...  ...     ...     ...     ...   ...    ...
# 103  106   11       1     175      10   3.9      3
# 104  107   16       0     160      10   3.9      3
# 105  108   21       1     180      15   5.6      3
# 106  109   26       0     150      15   5.6      3
# 107  110   31       1     190      20   8.3      3
#
# [108 rows x 7 columns]

# %%
corr=df.corr()
corr
# Out:
#               ID       Age    Gender    Height    Weight       BMI     Label
# ID      1.000000 -0.298257 -0.005595 -0.008224 -0.572625 -0.615235  0.347199
# Age    -0.298257  1.000000 -0.091964 -0.076896  0.465106  0.474185 -0.134396
# Gender -0.005595 -0.091964  1.000000  0.876225  0.418415  0.342342 -0.281647
# Height -0.008224 -0.076896  0.876225  1.000000  0.428890  0.354340 -0.237683
# Weight -0.572625  0.465106  0.418415  0.428890  1.000000  0.972829 -0.565555
# BMI    -0.615235  0.474185  0.342342  0.354340  0.972829  1.000000 -0.589237
# Label   0.347199 -0.134396 -0.281647 -0.237683 -0.565555 -0.589237  1.000000

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df.to_csv('Obesity Classification.csv',index=False)

# %%
p=pd.read_csv('Obesity Classification.csv')

# %%
p
# Out:
#       ID  Age  Gender  Height  Weight   BMI  Label
# 0      1   25       1     175      80  25.3      0
# 1      2   30       0     160      60  22.5      0
# 2      3   35       1     180      90  27.3      2
# 3      4   40       0     150      50  20.0      3
# 4      5   45       1     190     100  31.2      1
# ..   ...  ...     ...     ...     ...   ...    ...
# 103  106   11       1     175      10   3.9      3
# 104  107   16       0     160      10   3.9      3
# 105  108   21       1     180      15   5.6      3
# 106  109   26       0     150      15   5.6      3
# 107  110   31       1     190      20   8.3      3
#
# [108 rows x 7 columns]
